# %%
#from google.colab import drive
#drive.mount('/content/drive/', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
#cd "/content/drive/My Drive/Information_Retrieval_HW1"
# Out:
# /content/drive/My Drive/Information_Retrieval_HW1

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline
from tqdm import tqdm
from typing import List,Dict
from IPython.display import Image
from IPython.core.display import HTML 
from pathlib import Path

# %%
from nltk.tokenize import word_tokenize 
from nltk.stem.porter import PorterStemmer
import nltk
nltk.download("stopwords")
nltk.download("punkt")
from string import punctuation, ascii_lowercase
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Debug
# """ you can change this cell """

# %%
DEBUG = False
"""
Recommended to start with a small number to get a feeling for the preprocessing with prints (N_ROWS_FOR_DEBUG = 2)
later increase this number for 5*10**3 in order to see that the code runs at reasonable speed. 
When setting Debug == False, our code implements bow.fit() in 15-20 minutes according to the tqdm progress bar. Your solution is not supposed to be much further than that.
"""
N_ROWS_FOR_DEBUG = 5*10**3

# %% [markdown]
# # Config

# %%
INPUT_FILE_PATH = Path("lyrics.csv")

BOW_PATH = Path("bow.csv")
N_ROWS = N_ROWS_FOR_DEBUG if DEBUG else None
CHUNCK_SIZE = 5 if DEBUG else 5*10**3
tqdm_n_iterations = N_ROWS//CHUNCK_SIZE +1 if DEBUG else 363*10**3//CHUNCK_SIZE + 1
COLS = [5]

# %% [markdown]
# ## 1.1 Bag of words model
# ### Implement the following methods:
#
# * `preprocess_sentence`:
#     * Lower case the word
#     * Ignores it if it's in the stopwords list
#     * Removes characters which are not in the allowed symbols
#     * Stems it and appends it to the output sentence
#     * Discards words with length <= 1
#
#
# * `update_counts_and_probabilities`:
#
#     * Update self.unigram count (the amount of time each word is in the text)
#     * Update self.bigram count (two consecutive word occurances)
#     * Update self.trigram count (three consecutive word occurances)
#     * Update inverted index: a dictionary with words as keys and the values is a dictionary - {'DocID' : word_count}
#
# * `compute_word_document_frequency`:
#
#    * For each word count the number of docs it appears in. For example , for the word 'apple' -
# $$\sum_{i \in docs} I(apple \in doc_i), I := Indicator function$$
#
#
# * `update_inverted_index_with_tf_idf_and_compute_document_norm`:
#
#     * Update the inverted index (which currently hold word counts) with tf idf weighing. We will compute tf by dividing with the number of words in each document.
#     * As we want to calculate the document norm, incrementally update the document norm. pay attention that later we apply sqrt to it to finish the process.
#
# #### The result of this code is a bag of words model that already counts for TF-IDF weighing

# %%
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
allowed_symbols = set(l for l in ascii_lowercase)

# %%
def preprocess_sentence(sentence : str) -> List[str]:
    output_sentence = []
    for word in word_tokenize(sentence):
        word = word.lower()
        if word in stop_words:
            continue
        not_allowed_symbols = set(word)-allowed_symbols
        for x in not_allowed_symbols: word = word.replace(x, "")
        word = stemmer.stem(word)

        if len(word)<=1:
            continue
        output_sentence.append(word)
        
        
    return output_sentence
    

def get_data_chuncks() -> List[str]:
    for i ,chunck in enumerate(pd.read_csv(INPUT_FILE_PATH, usecols = COLS, chunksize = CHUNCK_SIZE, nrows = N_ROWS)):
        chunck = chunck.values.tolist()
        yield [chunck[i][0] for i in range(len(chunck))] 


class TfIdf:
    def __init__(self):
        self.unigram_count =  Counter()
        self.bigram_count = Counter()
        self.trigram_count = Counter()
        self.document_term_frequency = Counter()
        self.word_document_frequency = {}
        self.inverted_index = {}
        self.doc_norms = {}
        self.n_docs = -1
        self.sentence_preprocesser = preprocess_sentence
        self.bow_path = BOW_PATH

    def update_counts_and_probabilities(self, sentence :List[str],document_id:int) -> None:
        sentence_len = len(sentence)
        self.document_term_frequency[document_id] = sentence_len
        for i,word in enumerate(sentence):
            self.unigram_count.update([word])
            if (word) not in self.inverted_index:
                self.inverted_index[(word)] = {document_id : sentence.count(word)}
            else:
                self.inverted_index[(word)].update({document_id : sentence.count(word)})

            # No need to add bigrams and trigrams to self.inverted_index
            if i>=1:
                bigram = (sentence[i-1], word)
                #bigram_cnt =  ''.join(sentence).count(sentence[i-1]+word)
                self.bigram_count.update([bigram])
                #if bigram not in self.inverted_index:   
                #    self.inverted_index[bigram] = {document_id : bigram_cnt}
                #else:
                #    self.inverted_index[bigram].update({document_id : bigram_cnt})

            if i>=2:
                trigram = (sentence[i-2], sentence[i-1], word)
                #trigram_cnt = ''.join(sentence).count(sentence[i-2]+sentence[i-1]+word)
                self.trigram_count.update([trigram])
                #if trigram not in self.inverted_index:
                #    self.inverted_index[trigram] = {document_id : trigram_cnt}
                #else:
                #    self.inverted_index[trigram].update({document_id: trigram_cnt})

            
            
            
            
            
        
        
    def fit(self) -> None:
        skipped = 0
        for chunck in tqdm(get_data_chuncks(), total = tqdm_n_iterations):
            for sentence in chunck:
                self.n_docs += 1 
                if not isinstance(sentence, str):
                    skipped +=1
                    continue
                sentence = self.sentence_preprocesser(sentence)
                if sentence:
                    self.update_counts_and_probabilities(sentence,self.n_docs)
        self.save_bow() # bow is 'bag of words'
        self.compute_word_document_frequency()
        self.update_inverted_index_with_tf_idf_and_compute_document_norm()
        print('total of skipped documents : {} out of {}'.format(skipped, self.n_docs))
             
    def compute_word_document_frequency(self):
        for word in self.inverted_index.keys():
            self.word_document_frequency[word] = len(self.inverted_index[word].keys())
            
    def update_inverted_index_with_tf_idf_and_compute_document_norm(self):
        for word in self.inverted_index:
            for doc in self.inverted_index[word]:
                tf_nom = self.inverted_index[word][doc] # number of occurences of term in doc
                tf_denom =  self.document_term_frequency[doc] #normalize by num of terms in doc
                tf = tf_nom/tf_denom 
                
                idf_nom = self.n_docs #number of documents in corpus
                idf_denom = self.word_document_frequency[word] #number of documents where term occured at least once
                idf = np.log(idf_nom/idf_denom)
                #update doc norms with the (tf * idf) **2 for each word 
                self.inverted_index[word][doc] = tf * idf
                if doc not in self.doc_norms:
                    self.doc_norms[doc] = (tf * idf) **2
                else:    
                    self.doc_norms[doc] += (tf * idf) **2 
            
        
        
        
        
        
        for doc in self.doc_norms.keys():
            self.doc_norms[doc] = np.sqrt(self.doc_norms[doc]) 
            
    def save_bow(self):
        pd.DataFrame([self.inverted_index]).T.to_csv(self.bow_path)
                
tf_idf = TfIdf()
tf_idf.fit()
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
#   1%|▏         | 1/73 [00:17<21:19, 17.77s/it]
#   3%|▎         | 2/73 [00:35<21:09, 17.89s/it]
#   4%|▍         | 3/73 [00:52<20:19, 17.41s/it]
#   5%|▌         | 4/73 [01:11<20:43, 18.02s/it]
#   7%|▋         | 5/73 [01:31<20:57, 18.49s/it]
#   8%|▊         | 6/73 [01:49<20:35, 18.44s/it]
#  10%|▉         | 7/73 [02:10<21:06, 19.19s/it]
#  11%|█         | 8/73 [02:27<20:11, 18.63s/it]
#  12%|█▏        | 9/73 [02:49<20:43, 19.44s/it]
#  14%|█▎        | 10/73 [03:04<19:13, 18.30s/it]
#  15%|█▌        | 11/73 [03:28<20:35, 19.93s/it]
#  16%|█▋        | 12/73 [03:50<20:46, 20.43s/it]
#  18%|█▊        | 13/73 [04:07<19:27, 19.46s/it]
#  19%|█▉        | 14/73 [04:24<18:22, 18.68s/it]
#  21%|██        | 15/73 [04:44<18:24, 19.04s/it]
#  22%|██▏       | 16/73 [05:01<17:42, 18.63s/it]
#  23%|██▎       | 17/73 [05:22<18:00, 19.29s/it]
#  25%|██▍       | 18/73 [05:41<17:38, 19.25s/it]
#  26%|██▌       | 19/73 [05:57<16:30, 18.35s/it]
#  27%|██▋       | 20/73 [06:17<16:28, 18.64s/it]
#  29%|██▉       | 21/73 [06:34<15:44, 18.16s/it]
#  30%|███       | 22/73 [06:56<16:26, 19.35s/it]
#  32%|███▏      | 23/73 [07:13<15:37, 18.75s/it]
#  33%|███▎      | 24/73 [07:36<16:15, 19.91s/it]
#  34%|███▍      | 25/73 [08:00<16:49, 21.04s/it]
#  36%|███▌      | 26/73 [08:29<18:27, 23.55s/it]
#  37%|███▋      | 27/73 [08:51<17:34, 22.93s/it]
#  38%|███▊      | 28/73 [09:09<16:15, 21.68s/it]
#  40%|███▉      | 29/73 [09:26<14:53, 20.32s/it]
#  41%|████      | 30/73 [09:44<14:04, 19.63s/it]
#  42%|████▏     | 31/73 [10:06<14:07, 20.18s/it]
#  44%|████▍     | 32/73 [10:27<14:02, 20.55s/it]
#  45%|████▌     | 33/73 [10:46<13:18, 19.96s/it]
#  47%|████▋     | 34/73 [11:05<12:46, 19.66s/it]
#  48%|████▊     | 35/73 [11:27<12:50, 20.27s/it]
#  49%|████▉     | 36/73 [11:45<12:11, 19.76s/it]
#  51%|█████     | 37/73 [12:04<11:37, 19.37s/it]
#  52%|█████▏    | 38/73 [12:23<11:21, 19.47s/it]
#  53%|█████▎    | 39/73 [12:43<11:06, 19.60s/it]
#  55%|█████▍    | 40/73 [13:01<10:28, 19.05s/it]
#  56%|█████▌    | 41/73 [13:21<10:15, 19.24s/it]
#  58%|█████▊    | 42/73 [13:42<10:11, 19.73s/it]
#  59%|█████▉    | 43/73 [14:00<09:40, 19.37s/it]
#  60%|██████    | 44/73 [14:17<08:59, 18.60s/it]
#  62%|██████▏   | 45/73 [14:37<08:55, 19.12s/it]
#  63%|██████▎   | 46/73 [14:57<08:38, 19.19s/it]
#  64%|██████▍   | 47/73 [15:14<08:06, 18.70s/it]
#  66%|██████▌   | 48/73 [15:32<07:44, 18.60s/it]
#  67%|██████▋   | 49/73 [15:53<07:39, 19.14s/it]
#  68%|██████▊   | 50/73 [16:17<07:54, 20.63s/it]
#  70%|██████▉   | 51/73 [16:35<07:18, 19.94s/it]
#  71%|███████   | 52/73 [16:59<07:24, 21.15s/it]
#  73%|███████▎  | 53/73 [17:17<06:42, 20.15s/it]
#  74%|███████▍  | 54/73 [17:37<06:18, 19.93s/it]
#  75%|███████▌  | 55/73 [17:54<05:47, 19.33s/it]
#  77%|███████▋  | 56/73 [18:15<05:33, 19.64s/it]
#  78%|███████▊  | 57/73 [18:31<04:59, 18.71s/it]
#  79%|███████▉  | 58/73 [18:51<04:43, 18.92s/it]
#  81%|████████  | 59/73 [19:12<04:33, 19.51s/it]
#  82%|████████▏ | 60/73 [19:29<04:03, 18.73s/it]
#  84%|████████▎ | 61/73 [19:47<03:45, 18.76s/it]
#  85%|████████▍ | 62/73 [20:09<03:37, 19.76s/it]
#  86%|████████▋ | 63/73 [20:36<03:39, 21.94s/it]
#  88%|████████▊ | 64/73 [20:56<03:11, 21.22s/it]
#  89%|████████▉ | 65/73 [21:13<02:39, 19.90s/it]
#  90%|█████████ | 66/73 [21:29<02:11, 18.81s/it]
#  92%|█████████▏| 67/73 [21:46<01:48, 18.14s/it]
#  93%|█████████▎| 68/73 [22:06<01:33, 18.64s/it]
#  95%|█████████▍| 69/73 [22:27<01:17, 19.41s/it]
#  96%|█████████▌| 70/73 [22:50<01:01, 20.54s/it]
#  97%|█████████▋| 71/73 [23:12<00:42, 21.07s/it]
#  99%|█████████▊| 72/73 [23:29<00:19, 19.89s/it]
# 100%|██████████| 73/73 [23:38<00:00, 19.43s/it]
# total of skipped documents : 95680 out of 362236

# %%
class DocumentRetriever:
    def __init__(self, tf_idf):
        self.sentence_preprocesser = preprocess_sentence  
        self.vocab = set(tf_idf.unigram_count.keys())
        self.n_docs = tf_idf.n_docs
        self.inverted_index = tf_idf.inverted_index
        self.word_document_frequency = tf_idf.word_document_frequency
        self.doc_norms = tf_idf.doc_norms
        
    def rank2(self,query : Dict[str,int],documents: Dict[str , Dict[str, float]] ,metric: str ) -> Dict[str, float]:
        result = {} # key: DocID , value : float , simmilarity to query
        query_len = np.sum(np.array(list(query.values())))
        #query_norm = np.sqrt(np.sum(np.square(list(query.values()))))
        query_norm = 0
        tf_idf_query = []
        tf_idf_docs =   {k: [] for k in range(self.n_docs+1)} #each key is a doc_id and each value is an empty list
        for term in query:
            tf = query[term]/query_len # divide number of occurences of term in query by query length
            idf = self.n_docs/self.word_document_frequency[term] #get idf from dict
            tf_idf_query.append(tf * np.log(idf)) #append to tf_idf vector
            query_norm += (tf * np.log(idf)) ** 2 #increment norm
            for doc in tf_idf_docs: # iterate all docs of the inverted_dict[term]
                tf_idf_doc = self.inverted_index[term][doc] if doc in self.inverted_index[term] else 0 #it is possible that there is no occurence of the term in a given document therefore tf=0-->tf*idf =0
                tf_idf_docs[doc].append(tf_idf_doc)
        tf_idf_query = np.array(tf_idf_query)
        query_norm = np.sqrt(query_norm)
        for doc in tf_idf_docs:
            tf_idf_doc = np.array(tf_idf_docs[doc])
            doc_norm = self.doc_norms[doc] if doc in self.doc_norms else 0 #it is also possible that we skipped sentences in the .fit() method therfore some documents will not have any norm
            if metric== 'cosine':
                result[doc] = np.dot(tf_idf_query, tf_idf_doc)/ (query_norm * doc_norm)
            else:
                result[doc] = np.dot(tf_idf_query, tf_idf_doc)

        return result
    
    def rank(self, query: Dict[str, int], documents: Dict[str, Dict[str, float]], metric: str) -> Dict[str, float]:
        result = {}  # key: DocID , value : float , simmilarity to query
        query_len = np.sum(np.array(list(query.values())))
        query_norm = 0
        tf_idf_query = []
        tf_idf_docs = {}  # each key is a doc_id and each value is an empty list
        for idx, term in enumerate(query):
            tf = query[term] / query_len  # divide number of occurences of term in query by query length
            idf = self.n_docs / self.word_document_frequency[term]  # get idf from dict
            tf_idf_query.append(tf * np.log(idf))  # append to tf_idf vector
            query_norm += (tf * np.log(idf)) ** 2  # increment norm
            for doc in documents[term]:  # iterate all docs of the inverted_dict[term]
                if doc not in tf_idf_docs: #get precalculated tf-idf for word and doc
                    tf_idf_doc = np.zeros(len(query))
                    tf_idf_doc[idx] = documents[term][doc]
                    tf_idf_docs[doc] = tf_idf_doc
                else:
                    tf_idf_docs[doc][idx] = documents[term][doc]


        tf_idf_query = np.array(tf_idf_query)
        query_norm = np.sqrt(query_norm)
        for doc in tf_idf_docs:
            tf_idf_doc = np.array(tf_idf_docs[doc])
            doc_norm = self.doc_norms[doc]
            if metric == 'cosine':
                result[doc] = np.dot(tf_idf_query, tf_idf_doc) / (query_norm * doc_norm)
            else:
                result[doc] = np.dot(tf_idf_query, tf_idf_doc)

        return result

        
    
    def sort_and_retrieve_k_best(self, scores: Dict[str, float],k :int):
        return sorted(scores, key=scores.get, reverse=True)[:k]


    
    def reduce_query_to_counts(self, query : List)->  Counter:
        return Counter(query)
        
        
    def get_top_k_documents(self,query : str, metric: str , k = 5) -> List[str]:
        query = self.sentence_preprocesser(query)
        query = [word for word in query if word in self.vocab] # filter nan 
        query_bow = self.reduce_query_to_counts(query)
        relavant_documents = {word : self.inverted_index.get(word) for word in query}
        ducuments_with_similarity = self.rank(query_bow,relavant_documents, metric)
        return self.sort_and_retrieve_k_best(ducuments_with_similarity,k)
        
dr = DocumentRetriever(tf_idf)

# %% [markdown]
# ## 1.4 NgramSpellingCorrector
# Now we will implement a Ngarm (character Ngrams) spelling corrector. That is, we have an out of vocabulary word (w) and we want to retrieve the most similar words (in our vocabulary) to this word.
# we will model the similarity of two words by-
#
# $$sim(v,w) := prior \cdot likelihood = p(w) \cdot P(v|w) $$
# $$P(v|w) := JaccardIndex =  \frac{|X \cap Y|}{|X \cup Y|}$$
#
# Where v is an out of vocabulary word (typo or spelling mistake), w is in a vocabulary word, X is the ngram set of v and Y is the ngram set of w.
# For example, if n == 3, the set of ngrams for word "banana" is set("ban","ana","nan","ana") = {"ban","ana","nan"}
#
# In order to do it efficently, we will first construct an index from the possible Ngrams we have seen in our corpus to the words that those Ngrams appear in, in order prevent comparing w to all of the words in our corpus.
# Then, we will implement a function that computes this similarity.
#
# * Make sure you compute the JaccardIndex efficently!

# %%
def get_bigrams(word):
    for ngram in nltk.ngrams(word, 2):
        yield "".join(list(ngram))
    
def get_trigrams(word):
    for ngram in nltk.ngrams(word, 3):
        yield "".join(list(ngram))

# %%
class NgramSpellingCorrector:
    def __init__(self, unigram_counts: Counter, get_n_gram: callable):
        self.unigram_counts = unigram_counts
        self.ngram_index = {}
        self.get_n_grams = get_n_gram
    
    def build_index(self) -> None:
        mapping ={}
        for word in self.unigram_counts: #iterate words
            for n_gram in self.get_n_grams(word): #get n-grams for word 
                if n_gram not in mapping:
                    mapping[n_gram] = set([word]) # if this is a new n_gram create a new set with one item in it (the current word) 
                else:
                    mapping[n_gram].add(word) #if we already saw this n_gram, add element to set (avoid duplication)
        
        
        self.mapping = mapping
        
    def get_top_k_words(self,word:str,k=5) -> List[str]:
        #result set is a dict [Str-->float] , keys are word values are sim (v,w)
        result = {}
        # P(w) is the number of occurences of the word divided by the number of words in the corpus
        normalizer = np.sum(np.array(list(self.unigram_counts.values())))
        normalized_unigram_count = {k: self.unigram_counts[k]/normalizer for k in self.unigram_counts} 
        X = set(self.get_n_grams(word))
        possible_words_to_check = set()
        for x in X: # efficiently serach our mapping to find all the possible words we should iterate
            if x not in self.mapping:
                continue
            possible_words_to_check.update(self.mapping[x]) #add possible words for n-grams to the set
        
        for vocab_word in possible_words_to_check:
            Y = set(self.get_n_grams(vocab_word))
            p_w = normalized_unigram_count[vocab_word]
            p_v_given_w = len(X.intersection(Y))/len(X.union(Y)) 
            result[vocab_word] = p_w * p_v_given_w
        
        return sorted(result, key=result.get, reverse=True)[:k]

        
        
        
        
        
        
        
        


class BigramSpellingCorrector(NgramSpellingCorrector):
    def __init__(self, unigram_counts: Counter):
        super().__init__(unigram_counts, get_bigrams)
        
        
class TrigramSpellingCorrector(NgramSpellingCorrector):
    def __init__(self, unigram_counts: Counter):
        super().__init__(unigram_counts, get_trigrams)

# %%
out_of_vocab_word = 'supercalifragilisticexpialidocious'
bigram_spelling_corrector = BigramSpellingCorrector(tf_idf.unigram_count)
bigram_spelling_corrector.build_index()
bigram_spelling_corrector.get_top_k_words(out_of_vocab_word)
# Out:
# ['like', 'caus', 'life', 'still', 'time']

# %%
trigram_spelling_corrector = TrigramSpellingCorrector(tf_idf.unigram_count)
trigram_spelling_corrector.build_index()
trigram_spelling_corrector.get_top_k_words(out_of_vocab_word)
# Out:
# ['life', 'still', 'call', 'listen', 'hous']

# %% [markdown]
# ## 1.5 Language model
# Calculate the log likelihood of a sentence. Once with a bigram markovian langauge model, and once with a trigram model.
# for example - the likelihood of the senetence "spiderman spiderman does whatever a spider can" for the bigram model is:
# $$p(spiderman)\cdot p(spiderman|spiderman) \cdot  (does|spiderman) \cdot (whatever|does) \cdot  (a|whatever) \cdot  (spider|a) \cdot (can|spider)$$
#
# And for the trigram model:
# $$p(spiderman,spiderman)\cdot p(does|spiderman,spiderman) \cdot  (whatever|spiderman,does) \cdot (a|does,whatever) \cdot  (spider|whatever,a) \cdot  (can|a, spider)$$
#
# Since we do not want a zero probability sentence use Laplace smoothing, as you have seen in the lecture, or here https://en.wikipedia.org/wiki/Additive_smoothing

# %%
## for the probability smoothing
NUMERATOR_SMOOTHING = 1
DENOMINATOR_SMOOTHING = 10**4
def sentence_log_probabilty(unigrams : Counter, bigrams  : Counter, trigrams: Counter, sentence: str):
    bigram_log_likelilhood, trigram_log_likelilhood = 0, 0
    sentence = sentence.split()
    for i, word in enumerate(sentence):
        #print(i,word)
        ### YOUR CODE HERE
        #to perform additive smoothing we need to add NUMERATOR_SMOOTHING to numerator
        # and \V\ * DENOMINATOR_SMOOTHING to denominator. 
        numerator_fix = NUMERATOR_SMOOTHING
        #denominator_fix = sum(unigrams.values()) * DENOMINATOR_SMOOTHING # \V\ * smoothing
        denominator_fix = DENOMINATOR_SMOOTHING
        if i==0:
            # bigram term (no trigram term) 
            p_nom = unigrams[word] # p(w0)
            p_denom = sum(unigrams.values()) #p(.) , no condition sum all unigrams 
            current_bigram_term = (numerator_fix + p_nom)/(denominator_fix + p_denom) 

            #updates
            bigram_log_likelilhood += np.log(current_bigram_term)
            continue
        elif i==1:
            #bigram term
            p_nom = bigrams[(sentence[i-1], word)] # p(w0,w1)
            p_denom = unigrams[sentence[i-1]] # p(w0)
            current_bigram_term = (numerator_fix + p_nom)/(denominator_fix + p_denom) 


            
            #trigram term 
            p_nom = bigrams[(sentence[i-1], word)] # p(w0, w1)
            p_denom = sum(bigrams.values()) #p(.),  no condition, sum all bigrams 
            current_trigram_term = (numerator_fix + p_nom)/(denominator_fix + p_denom)
            #updates
            bigram_log_likelilhood += np.log(current_bigram_term)
            trigram_log_likelilhood += np.log(current_trigram_term)

            continue
        else: #i>2
            #bigram term (same as i==1)
            p_nom = bigrams[(sentence[i-1], word)] # p(wi-1,wi)
            p_denom = unigrams[sentence[i-1]] # p(wi-1)
            current_bigram_term = (numerator_fix + p_nom)/(denominator_fix + p_denom)


            #trigram term
            p_nom = trigrams[(sentence[i-2] , sentence[i-1], word)] # p(wi-2,wi-1,wi)
            p_denom = bigrams[(sentence[i-2] , sentence[i-1])] # p(wi-2, wi-1)
            current_trigram_term = (numerator_fix + p_nom)/(denominator_fix + p_denom)
            #updates
            bigram_log_likelilhood += np.log(current_bigram_term)
            trigram_log_likelilhood += np.log(current_trigram_term)

        
        
        
        
        
        
        
        ### END YOUR CODE
    print("Bigram log likelihood is {}".format(bigram_log_likelilhood))
    print("Trigram log likelihood is {}".format(trigram_log_likelilhood))
    return (bigram_log_likelilhood, trigram_log_likelilhood )
sentence = "spider man spider man does whatever a spider can"

bi_likelilhood, tri_likelilhood = sentence_log_probabilty(tf_idf.unigram_count, tf_idf.bigram_count, tf_idf.trigram_count, sentence)
# Out:
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0

# %% [markdown]
# ## 1.51 Language model: B
# For each model what is the next word prediciton for the sentnence "i am"?

# %%
""" Please notice that ['i', 'am'] does not exist in our BOW (due to stemming), obviously we will get an irrelevant result
    So there is no need to run the code below. Anyway This is a naive implementation of next word prediction.
    A more clever implementation could use the inverted_index to get the mutual documents that both words
    'i' and 'am' appear in. """

next_word_bigram = ''
next_word_trigram = ''
best_ll_bigram = -9999
best_ll_trigram = -9999
base_sentence = 'i am'
for i,word in enumerate(tf_idf.unigram_count):
    print('parsing word {} out of {}'.format(i+1, len(tf_idf.unigram_count)))
    sentence = base_sentence + (' ') + word
    ll_bigram, ll_trigram = sentence_log_probabilty(tf_idf.unigram_count, tf_idf.bigram_count, tf_idf.trigram_count, sentence)
    if ll_bigram>best_ll_bigram:
        next_word_bigram = word
        best_ll_bigram = ll_bigram
    if ll_trigram>best_ll_trigram:
        next_word_trigram = word
        best_ll_trigram = ll_trigram
        
    
print ('Next word for Bigram Model is : ',next_word_bigram)
print ('Next word for Trigram Model is : ', next_word_trigram)
# Out:
# parsing word 1 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 2 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 3 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 4 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 5 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 6 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 7 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 8 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 9 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 10 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 11 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 12 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 13 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 14 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 15 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 16 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 17 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 18 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 19 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 20 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 21 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 22 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 23 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 24 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 25 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 26 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 27 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 28 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 29 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 30 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 31 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 32 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 33 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 34 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 35 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 36 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 37 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 38 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 39 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 40 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 41 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 42 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 43 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 44 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 45 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 46 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 47 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 48 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 49 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 50 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 51 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 52 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 53 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 54 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 55 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 56 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 57 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 58 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 59 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 60 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 61 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 62 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 63 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 64 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 65 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 66 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 67 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 68 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 69 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 70 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 71 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 72 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 73 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 74 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 75 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 76 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 77 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 78 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 79 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 80 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 81 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 82 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 83 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 84 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 85 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 86 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 87 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 88 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 89 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 90 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 91 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 92 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 93 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 94 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 95 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 96 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 97 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 98 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 99 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 100 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 101 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 102 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 103 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 104 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 105 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 106 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 107 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 108 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 109 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 110 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 111 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 112 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 113 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 114 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 115 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 116 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 117 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 118 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 119 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 120 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 121 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 122 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 123 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 124 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 125 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 126 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 127 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 128 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 129 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 130 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 131 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 132 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 133 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 134 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 135 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 136 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 137 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 138 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 139 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 140 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 141 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 142 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 143 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 144 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 145 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 146 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 147 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 148 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 149 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 150 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 151 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 152 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 153 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 154 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 155 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 156 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 157 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 158 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 159 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 160 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 161 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 162 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 163 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 164 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 165 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 166 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 167 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 168 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 169 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 170 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 171 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 172 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 173 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 174 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 175 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 176 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 177 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 178 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 179 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 180 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 181 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 182 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 183 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 184 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 185 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 186 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 187 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 188 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 189 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 190 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 191 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 192 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 193 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 194 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 195 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 196 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 197 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 198 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 199 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 200 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 201 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 202 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 203 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 204 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 205 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 206 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 207 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 208 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 209 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 210 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 211 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 212 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 213 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 214 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 215 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 216 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 217 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 218 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 219 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 220 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 221 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 222 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 223 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 224 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 225 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 226 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 227 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 228 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 229 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 230 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 231 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 232 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 233 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 234 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 235 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 236 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 237 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 238 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 239 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 240 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 241 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 242 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 243 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 244 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 245 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 246 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 247 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 248 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 249 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 250 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 251 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 252 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 253 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 254 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 255 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 256 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 257 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 258 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 259 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 260 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 261 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 262 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 263 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 264 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 265 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 266 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 267 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 268 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 269 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 270 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 271 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 272 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 273 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 274 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 275 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 276 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 277 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 278 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 279 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 280 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 281 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 282 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 283 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 284 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 285 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 286 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 287 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 288 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 289 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 290 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 291 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 292 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 293 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 294 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 295 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 296 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 297 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 298 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 299 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 300 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 301 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 302 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 303 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 304 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 305 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 306 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 307 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 308 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 309 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 310 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 311 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 312 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 313 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 314 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 315 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 316 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 317 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 318 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 319 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 320 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 321 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 322 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 323 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 324 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 325 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 326 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 327 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 328 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 329 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 330 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 331 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 332 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 333 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 334 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 335 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 336 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 337 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 338 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 339 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 340 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 341 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 342 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 343 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 344 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 345 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 346 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 347 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 348 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 349 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 350 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 351 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 352 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 353 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 354 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 355 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 356 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 357 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 358 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 359 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 360 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 361 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 362 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 363 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 364 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 365 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 366 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 367 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 368 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 369 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 370 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 371 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 372 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 373 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 374 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 375 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 376 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 377 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 378 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 379 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 380 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 381 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 382 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 383 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 384 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 385 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 386 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 387 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 388 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 389 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 390 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 391 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 392 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 393 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 394 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 395 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 396 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 397 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 398 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 399 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 400 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 401 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 402 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 403 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 404 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 405 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 406 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 407 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 408 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 409 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 410 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 411 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 412 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 413 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 414 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 415 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 416 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 417 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 418 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 419 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 420 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 421 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 422 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 423 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 424 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 425 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 426 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 427 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 428 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 429 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 430 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 431 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 432 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 433 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 434 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 435 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 436 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 437 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 438 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 439 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 440 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 441 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 442 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 443 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 444 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 445 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 446 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 447 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 448 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 449 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 450 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 451 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 452 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 453 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 454 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 455 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 456 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 457 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 458 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 459 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 460 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 461 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 462 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 463 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 464 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 465 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 466 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 467 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 468 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 469 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 470 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 471 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 472 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 473 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 474 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 475 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 476 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 477 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 478 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 479 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 480 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 481 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 482 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 483 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 484 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 485 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 486 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 487 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 488 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 489 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 490 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 491 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 492 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 493 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 494 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 495 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 496 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 497 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 498 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 499 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 500 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 501 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 502 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 503 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 504 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 505 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 506 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 507 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 508 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 509 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 510 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 511 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 512 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 513 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 514 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 515 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 516 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 517 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 518 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 519 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 520 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 521 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 522 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 523 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 524 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 525 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 526 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 527 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 528 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 529 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 530 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 531 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 532 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 533 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 534 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 535 out of 389141
# ...
# Trigram log likelihood is 0.0
# parsing word 563 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 564 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 565 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 566 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 567 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 568 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 569 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 570 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 571 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 572 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 573 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 574 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 575 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 576 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 577 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 578 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 579 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 580 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 581 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 582 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 583 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 584 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 585 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 586 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 587 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 588 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 589 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 590 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 591 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 592 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 593 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 594 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 595 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 596 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 597 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 598 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 599 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 600 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 601 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 602 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 603 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 604 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 605 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 606 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 607 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 608 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 609 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 610 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 611 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 612 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 613 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 614 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 615 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 616 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 617 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 618 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 619 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 620 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 621 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 622 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 623 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 624 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 625 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 626 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 627 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 628 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 629 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 630 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 631 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 632 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 633 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 634 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 635 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 636 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 637 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 638 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 639 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 640 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 641 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 642 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 643 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 644 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 645 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 646 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 647 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 648 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 649 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 650 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 651 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 652 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 653 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 654 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 655 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 656 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 657 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 658 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 659 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 660 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 661 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 662 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 663 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 664 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 665 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 666 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 667 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 668 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 669 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 670 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 671 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 672 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 673 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 674 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 675 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 676 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 677 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 678 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 679 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 680 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 681 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 682 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 683 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 684 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 685 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 686 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 687 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 688 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 689 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 690 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 691 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 692 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 693 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 694 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 695 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 696 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 697 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 698 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 699 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 700 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 701 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 702 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 703 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 704 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 705 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 706 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 707 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 708 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 709 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 710 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 711 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 712 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 713 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 714 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 715 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 716 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 717 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 718 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 719 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 720 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 721 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 722 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 723 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 724 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 725 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 726 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 727 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 728 out of 389141
# Bigram log likelihood is 0.0
# Trigram log likelihood is 0.0
# parsing word 729 out of 389141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-493025d2da13> in <module>()
#       7     print('parsing word {} out of {}'.format(i+1, len(tf_idf.unigram_count)))
#       8     sentence = base_sentence + (' ') + word
# ----> 9     ll_bigram, ll_trigram = sentence_log_probabilty(tf_idf.unigram_count, tf_idf.bigram_count, tf_idf.trigram_count, sentence)
#      10     if ll_bigram>best_ll_bigram:
#      11         next_word_bigram = word
#
# <ipython-input-30-f2533baac59c> in sentence_log_probabilty(unigrams, bigrams, trigrams, sentence)
#      30             #trigram term
#      31             p_nom = bigrams[(sentence[i-1], word)] # p(w0, w1)
# ---> 32             p_denom = sum(bigrams.values()) #p(.),  no condition, sum all bigrams
#      33             current_trigram_term = (numerator_fix + p_nom)/(denominator_fix + p_denom)
#      34             #updates
#
# KeyboardInterrupt:
